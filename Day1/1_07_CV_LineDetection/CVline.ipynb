# %%
# %cd /content/drive/MyDrive/colab
# Out:
# /content/drive/MyDrive/colab

# %%
# !git clone https://github.com/SESL-KMU/Autonomous-AI.git
# Out:
# Cloning into 'Autonomous-AI'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 18858 (delta 1), reused 1 (delta 0), pack-reused 18852
# Receiving objects: 100% (18858/18858), 809.95 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (386/386), done.
# Checking out files: 100% (18687/18687), done.

# %%
# %cd Autonomous-AI/Day1/1_07_CV_LineDetection/line_example/
# Out:
# /content/drive/My Drive/colab/Autonomous-AI/Day1/1_07_CV_LineDetection/line_example

# %%
# %ls
# Out:
# 1_whiteline.py  3_binarization.py  5_hough.py        7_best_line.py
# 2_RoI.py        4_blur_Edge.py     6_remove_line.py  road.png

# %%
# %run 1_whiteline.py
# Out:
# <PIL.Image.Image image mode=RGB size=698x402 at 0x7FF61678A198>
# <PIL.Image.Image image mode=RGB size=698x402 at 0x7FF60C933550>

# %%
# %run 2_RoI.py
# Out:
# <PIL.Image.Image image mode=RGB size=698x402 at 0x7FF60C8CA4E0>
# <PIL.Image.Image image mode=RGB size=698x402 at 0x7FF60C8CA438>

# %%
# %run 3_binarization.py
# Out:
# thres
# <PIL.Image.Image image mode=L size=698x402 at 0x7FF60C8CA4A8>
# otsu
# <PIL.Image.Image image mode=L size=698x402 at 0x7FF60C8CA550>
# adap
# <PIL.Image.Image image mode=L size=698x402 at 0x7FF60C8CA470>
# image
# <PIL.Image.Image image mode=L size=698x402 at 0x7FF60C8CA630>

# %%
# %run 4_blur_Edge.py
# Out:
# <PIL.Image.Image image mode=RGB size=698x402 at 0x7FF60C8CA630>
# <PIL.Image.Image image mode=L size=698x402 at 0x7FF60C8CA5C0>

# %%
# %run 5_hough.py
# Out:
# <PIL.Image.Image image mode=RGB size=698x402 at 0x7FF60C8CA780>

# %%
# %run 6_remove_line.py
# Out:
# <PIL.Image.Image image mode=RGB size=698x402 at 0x7FF60C8CA898>

# %%
# %run 7_best_line.py
# Out:
# <PIL.Image.Image image mode=RGB size=698x402 at 0x7FF60C8CA9B0>

# %%
# %cd ..
# Out:
# /content/drive/My Drive/colab/Autonomous-AI/Day1/1_07_CV_LineDetection

# %%
# %ls
# Out:
# CVlineDetection_ans.py  CVlineDetection.py  requirements.txt
# CVlineDetection.ipynb   line_example/       test_images/

# %%
# %run CVlineDetection.py

# %%
# %run CVlineDetection_ans.py
