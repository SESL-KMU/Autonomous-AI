# %% [markdown]
# #<font color=blue>**CV기반 객체 인식**</font>
# 각 셀을 순서대로 shift + ENTER로 실행

# %% [markdown]
# ##<font color=green>**구글 드라이브 연결**</font>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##<font color=green>**SESL Autonomous-AI 설치**</font>

# %%
# %cd drive/MyDrive/
# !git clone https://github.com/SESL-KMU/Autonomous-AI.git
# Out:
# /content/drive/MyDrive
# Cloning into 'Autonomous-AI'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (165/165), done.
# remote: Total 19129 (delta 66), reused 168 (delta 34), pack-reused 18917
# Receiving objects: 100% (19129/19129), 884.03 MiB | 14.35 MiB/s, done.
# Resolving deltas: 100% (487/487), done.
# Checking out files: 100% (18766/18766), done.

# %% [markdown]
# ##<font color=green>**실습 경로로 이동**</font>

# %%
cd Autonomous-AI/Day2/2_01_CV_Object_Recognition
# Out:
# /content/drive/My Drive/Autonomous-AI/Day2/2_01_CV_Object_Recognition

# %% [markdown]
# ##<font color=green>**실습 코드 진행**</font>

# %%
# %run extract_cars.py
# Out:
# # car images: 8792
# # non-car images: 8970
# SVC model loaded
# X_scaler loaded
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LinearSVC from version 0.24.0 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.0 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F1CAEBC6588>
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F1CAEBC6978>

# %%
cd /content/drive/MyDrive/Autonomous-AI/Day2/2_01_CV_Object_Recognition
# Out:
# /content/drive/MyDrive/Autonomous-AI/Day2/2_01_CV_Object_Recognition
